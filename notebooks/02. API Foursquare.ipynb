# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#API-Foursquare." data-toc-modified-id="API-Foursquare.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>API Foursquare.</a></span></li><li><span><a href="#Mi-empresa" data-toc-modified-id="Mi-empresa-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Mi empresa</a></span><ul class="toc-item"><li><span><a href="#Primera-llamada:-Aeropuerto" data-toc-modified-id="Primera-llamada:-Aeropuerto-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Primera llamada: Aeropuerto</a></span><ul class="toc-item"><li><span><a href="#El-aeropuerto-más-cercano-es-:" data-toc-modified-id="El-aeropuerto-más-cercano-es-:-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>El aeropuerto más cercano es :</a></span></li></ul></li><li><span><a href="#Segunda-llamada:-Nurseries" data-toc-modified-id="Segunda-llamada:-Nurseries-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Segunda llamada: Nurseries</a></span><ul class="toc-item"><li><span><a href="#¿Cuál-de-las-Nurseries-está-más-cerca-de-mi-empresa?" data-toc-modified-id="¿Cuál-de-las-Nurseries-está-más-cerca-de-mi-empresa?-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>¿Cuál de las Nurseries está más cerca de mi empresa?</a></span></li><li><span><a href="#La-Nursery-más-cercana-es-:" data-toc-modified-id="La-Nursery-más-cercana-es-:-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>La Nursery más cercana es :</a></span></li></ul></li><li><span><a href="#Tercera-llamada:-Nightclubs" data-toc-modified-id="Tercera-llamada:-Nightclubs-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Tercera llamada: Nightclubs</a></span><ul class="toc-item"><li><span><a href="#¿Dónde-está-el-Nightclub-más-cercano-a-mi-empresa?" data-toc-modified-id="¿Dónde-está-el-Nightclub-más-cercano-a-mi-empresa?-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>¿Dónde está el Nightclub más cercano a mi empresa?</a></span></li><li><span><a href="#El-nightclub-más-cercano-es-:" data-toc-modified-id="El-nightclub-más-cercano-es-:-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>El nightclub más cercano es :</a></span></li></ul></li><li><span><a href="#Cuarta-llamada:-Starbucks" data-toc-modified-id="Cuarta-llamada:-Starbucks-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Cuarta llamada: Starbucks</a></span><ul class="toc-item"><li><span><a href="#El-Starbucks-más-cercano-es-:" data-toc-modified-id="El-Starbucks-más-cercano-es-:-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>El Starbucks más cercano es :</a></span></li></ul></li><li><span><a href="#Quinta-llamada:-Restaurante-Vegano" data-toc-modified-id="Quinta-llamada:-Restaurante-Vegano-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Quinta llamada: Restaurante Vegano</a></span><ul class="toc-item"><li><span><a href="#¿Cuál-es-el-restaurante-vegano-más-cercano-a-mi-empresa?" data-toc-modified-id="¿Cuál-es-el-restaurante-vegano-más-cercano-a-mi-empresa?-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>¿Cuál es el restaurante vegano más cercano a mi empresa?</a></span></li><li><span><a href="#El-Restaurante-vegano-más-cercano-es-:" data-toc-modified-id="El-Restaurante-vegano-más-cercano-es-:-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>El Restaurante vegano más cercano es :</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # API Foursquare.
#
# Una vez seleccionada la oficina perfecta que cumple nuestras necesidades vamos a comprobar mediante la API de Foursquare los siguientes puntos;
# - Los Account managers viajan mucho. Voy a busar un aeropuerto en un radio de 20kms.
# - El 30% de los empleados de la compañía tiene al menos un niño. Voy a buscar guarderías en un radio de 5km.
# - La edad de los trabajadores oscila entre 25 y 40 años. Voy a buscar discotecas en un radio de 10km.
# - A los ejecutivos les gusta mucho la cadena de cafés "Starbucks". Voy a buscar Starbucks en un radio de 300m.
# - La CEO de la compañía es vegana. Voy a buscar restaurantes veganos en un radio de 2km.

# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
from functools import reduce
import operator
import geopandas as gpd
from pymongo import MongoClient,GEOSPHERE
import shapely.geometry
import geopandas as gpd
from cartoframes.viz import Map, Layer, popup_element
import sys
sys.path.append("../")
import src.funcionesok as fun

# %%
company = "21 Mikonkatu, Helsinki FI 00100"

# %%
fun.geocode(company)
# Out:
# {'type': 'Point', 'coordinates': [60.17212, 24.94519]}

# %%
fun.geo_api(company)

# %%
load_dotenv()
# Out:
# True

# %%
tok1 = os.getenv("tok1")
tok2 = os.getenv("tok2")

# %%
suomi = pd.read_csv('../data/dataOK.csv', encoding = 'ISO - 8859-1')
suomi
# Out:
#        city country_code   latitude  longitude   name category_code  \
# 0  Helsinki          FIN  60.171821  24.945167  Apaja   games_video
#
#    number_of_employees  founded_year
# 0                   44          2001

# %%
#Busco los códigos en la API en los que voy a basar las llamadas;

"""
airport = "4bf58dd8d48988d1ed931735"

nurseries = "4f4533814b9074f6e4fb0107"

nightlife sport = "4d4b7105d754a06376d81259"

coffee_shop = "4bf58dd8d48988d1e0931735"

vegan_restaurant = "4bf58dd8d48988d1d3941735"

"""
# Out:
# '\nairport = "4bf58dd8d48988d1ed931735"\n\nnurseries = "4f4533814b9074f6e4fb0107"\n\nnightlife sport = "4d4b7105d754a06376d81259"\n\ncoffee_shop = "4bf58dd8d48988d1e0931735"\n\nvegan_restaurant = "4bf58dd8d48988d1d3941735"\n\n'

# %% [markdown]
# #  Mi empresa
# Teniendo en cuenta mi empresa hago llamadas a la API.

# %% [markdown]
# ## Primera llamada: Aeropuerto

# %%
donde = "21 Mikonkatu, Helsinki FI 00100"
def geocode(address):
    """
    Saca las coordenadas de una dirección que le des.
    """
    data = requests.get(f"https://geocode.xyz/{address}?json=1").json()
    try:
        return {
            "type":"Point",
            "coordinates":[float(data["longt"]),float(data["latt"])]}
    except:
        return data

# %%
emp1 = geocode(donde)
emp1
# Out:
# {'type': 'Point', 'coordinates': [24.94519, 60.17212]}

# %%
url1= 'https://api.foursquare.com/v2/venues/explore'

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"{emp1.get('coordinates')[1]},{emp1.get('coordinates')[0]}",
              "query": "Airport",
              "limit": 1,
              "radius": 20000,
             }

# %%
resp = requests.get(url=url1, params=params)
airdata = json.loads(resp.text)

# %%
airdata.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = airdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
airp = decoded.get("items")

# %%
mapa_nombre = ["venue","name"]
m_latitud = ["venue","location","lat"]
m_longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce (operator.getitem,mapa,diccionario)

# %%
print(getFromDict(airp[0],mapa_nombre))
# Out:
# Helsinki Airport (HEL) (Helsinki-Vantaan lentoasema)

# %%
print(getFromDict(airp[0],m_latitud))
# Out:
# 60.31912855684579

# %%
print(getFromDict(airp[0],m_longitud))
# Out:
# 24.968297481536865

# %%
aeropuerto = []
for dic in airp:
    ai = {}
    ai["name"] = getFromDict(dic,mapa_nombre)
    ai["latitud"] = getFromDict(dic,m_latitud)
    ai["longitud"] = getFromDict(dic,m_longitud)
    aeropuerto.append(ai)

# %%
aeropuerto[0]
# Out:
# {'name': 'Helsinki Airport (HEL) (Helsinki-Vantaan lentoasema)',
#  'latitud': 60.31912855684579,
#  'longitud': 24.968297481536865}

# %%
dataframefinal = pd.DataFrame(aeropuerto)
dataframefinal.head()
# Out:
#                                                 name    latitud   longitud
# 0  Helsinki Airport (HEL) (Helsinki-Vantaan lento...  60.319129  24.968297

# %%
gdf = gpd.GeoDataFrame(dataframefinal, geometry = gpd.points_from_xy(dataframefinal.longitud,dataframefinal.latitud))
gdf.head()
# Out:
#                                                 name    latitud   longitud  \
# 0  Helsinki Airport (HEL) (Helsinki-Vantaan lento...  60.319129  24.968297
#
#                     geometry
# 0  POINT (24.96830 60.31913)

# %%
#Creo un mapa con el punto selecccionado

# %%
Map(Layer(gdf, popup_hover = [popup_element("name","Airport")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### El aeropuerto más cercano es :
#     Helsinki Airport (HEL) (Helsinki-Vantaan lentoasema)
#     latitud: 60.319129
#     longitud: 24.968297

# %% [markdown]
# ## Segunda llamada: Nurseries

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"{emp1.get('coordinates')[1]},{emp1.get('coordinates')[0]}",
              "query": "Nursery School",
              "limit": 10,
              "radius": 5000
             }

# %%
resp = requests.get(url=url1, params=params)
nurdata = json.loads(resp.text)

# %%
nurdata.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = nurdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
nur = decoded.get("items")

# %%
mapan_nombre = ["venue","name"]
mn_latitud = ["venue","location","lat"]
mn_longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce (operator.getitem,mapa,diccionario)

# %%
print(getFromDict(nur[0],mapan_nombre))
print(getFromDict(nur[0],mn_latitud))
print(getFromDict(nur[0],mn_longitud))
# Out:
# Daghemmet B. E. Von Schantz
# 60.158121
# 24.936681

# %%
nurseries = []
for dic in nur:
    nr = {}
    nr["name"] = getFromDict(dic,mapa_nombre)
    nr["latitud"] = getFromDict(dic,m_latitud)
    nr["longitud"] = getFromDict(dic,m_longitud)
    nurseries.append(nr)

# %%
nurseries[0]
# Out:
# {'name': 'Daghemmet B. E. Von Schantz',
#  'latitud': 60.158121,
#  'longitud': 24.936681}

# %%
df_nur = pd.DataFrame(nurseries)
df_nur.head()
# Out:
#                              name    latitud   longitud
# 0     Daghemmet B. E. Von Schantz  60.158121  24.936681
# 1  lauttasaari english playschool  60.158857  24.877429
# 2             Päiväkoti Kesäheinä  60.202455  24.951274
# 3               Päiväkoti Marjala  60.209475  24.964812

# %%
import geopandas as gpd

# %%
gdf2 = gpd.GeoDataFrame(df_nur, geometry = gpd.points_from_xy(df_nur.longitud,df_nur.latitud))
gdf2.head()
# Out:
#                              name    latitud   longitud  \
# 0     Daghemmet B. E. Von Schantz  60.158121  24.936681
# 1  lauttasaari english playschool  60.158857  24.877429
# 2             Päiväkoti Kesäheinä  60.202455  24.951274
# 3               Päiväkoti Marjala  60.209475  24.964812
#
#                     geometry
# 0  POINT (24.93668 60.15812)
# 1  POINT (24.87743 60.15886)
# 2  POINT (24.95127 60.20246)
# 3  POINT (24.96481 60.20948)

# %%
Map(Layer(gdf2, popup_hover = [popup_element("name","Nursery School")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### ¿Cuál de las Nurseries está más cerca de mi empresa?

# %%
gdf2['geometry']=gdf2['geometry'].apply(lambda x:shapely.geometry.mapping(x))
gdf2
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
#                              name    latitud   longitud  \
# 0     Daghemmet B. E. Von Schantz  60.158121  24.936681
# 1  lauttasaari english playschool  60.158857  24.877429
# 2             Päiväkoti Kesäheinä  60.202455  24.951274
# 3               Päiväkoti Marjala  60.209475  24.964812
#
#                                             geometry
# 0  {'type': 'Point', 'coordinates': (24.936681, 6...
# 1  {'type': 'Point', 'coordinates': (24.877429136...
# 2  {'type': 'Point', 'coordinates': (24.951274170...
# 3  {'type': 'Point', 'coordinates': (24.964811971...

# %%
client = MongoClient()
db = client.ironhack
collection = db.nurseries
collection.create_index ([("geometry", GEOSPHERE)])
# Out:
# 'geometry_2dsphere'

# %%
data = gdf2.to_dict(orient='records')
collection.insert_many(data)

# %%
data
# Out:
# [{'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': (24.936681, 60.158121)},
#   '_id': ObjectId('602164a3bda0fd886bdf4fe1')},
#  {'name': 'lauttasaari english playschool',
#   'latitud': 60.158857316461074,
#   'longitud': 24.877429136253458,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.877429136253458, 60.158857316461074)},
#   '_id': ObjectId('602164a3bda0fd886bdf4fe2')},
#  {'name': 'Päiväkoti Kesäheinä',
#   'latitud': 60.20245514603548,
#   'longitud': 24.95127417000266,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.95127417000266, 60.20245514603548)},
#   '_id': ObjectId('602164a3bda0fd886bdf4fe3')},
#  {'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.964811971036774, 60.20947535503745)},
#   '_id': ObjectId('602164a3bda0fd886bdf4fe4')}]

# %%
cercano2 = db.nurseries.find({"geometry":{"$near":{"type":"Point", "coordinates":[60.171821,24.945167]}}})
list(cercano2)
# Out:
# [{'_id': ObjectId('60212ef3235f9908d38c87d0'),
#   'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': [24.936681, 60.158121]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe1'),
#   'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': [24.936681, 60.158121]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe4'),
#   'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.964811971036774, 60.20947535503745]}},
#  {'_id': ObjectId('60212ef3235f9908d38c87d3'),
#   'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.964811971036774, 60.20947535503745]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe3'),
# ...

# %% [markdown]
# ### La Nursery más cercana es :
#     Daghemmet B. E. Von Schantz
#     latitud': 60.158121
#     longitud': 24.936681

# %% [markdown]
# ## Tercera llamada: Nightclubs

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"{emp1.get('coordinates')[1]},{emp1.get('coordinates')[0]}",
              "query": "Nightlife Spot",
              "limit": 25,
              "radius": 7500 
         }
resp = requests.get(url=url1, params=params)
nidata = json.loads(resp.text)

# %%
nidata.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = nidata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
nic = decoded.get("items")

# %%
mapani_nombre = ["venue","name"]
mapani_latitud = ["venue","location","lat"]
mapani_longitud = ["venue","location","lng"]

# %%
print(getFromDict(nic[0],mapa_nombre))
print(getFromDict(nic[0],m_latitud))
print(getFromDict(nic[0],m_longitud))
# Out:
# Liberty or Death
# 60.16469982956184
# 24.944248795509335

# %%
nightclubs = []
for dic in nic:
    nc = {}
    nc["name"] = getFromDict(dic,mapa_nombre)
    nc["latitud"] = getFromDict(dic,m_latitud)
    nc["longitud"] = getFromDict(dic,m_longitud)
    nightclubs.append(nc)

# %%
nightclubs[0]
# Out:
# {'name': 'Liberty or Death',
#  'latitud': 60.16469982956184,
#  'longitud': 24.944248795509335}

# %%
df_nc = pd.DataFrame(nightclubs)
df_nc.head()
# Out:
#                        name    latitud   longitud
# 0          Liberty or Death  60.164700  24.944249
# 1                 KirjaClub  60.176467  24.956222
# 2                     Apéro  60.164211  24.929481
# 3  Olutravintola Pikkulintu  60.165893  24.936865
# 4   Plaza Wine & Craft Beer  60.169200  24.934983

# %%
gdf3 = gpd.GeoDataFrame(df_nc, geometry = gpd.points_from_xy(df_nc.longitud,df_nc.latitud))
gdf3.head()
# Out:
#                        name    latitud   longitud                   geometry
# 0          Liberty or Death  60.164700  24.944249  POINT (24.94425 60.16470)
# 1                 KirjaClub  60.176467  24.956222  POINT (24.95622 60.17647)
# 2                     Apéro  60.164211  24.929481  POINT (24.92948 60.16421)
# 3  Olutravintola Pikkulintu  60.165893  24.936865  POINT (24.93687 60.16589)
# 4   Plaza Wine & Craft Beer  60.169200  24.934983  POINT (24.93498 60.16920)

# %%
Map(Layer(gdf3, popup_hover = [popup_element("name","Night Club")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### ¿Dónde está el Nightclub más cercano a mi empresa?

# %%
gdf3['geometry']=gdf3['geometry'].apply(lambda x:shapely.geometry.mapping(x))
gdf3
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
#                         name    latitud   longitud  \
# 0           Liberty or Death  60.164700  24.944249
# 1                  KirjaClub  60.176467  24.956222
# 2                      Apéro  60.164211  24.929481
# 3   Olutravintola Pikkulintu  60.165893  24.936865
# 4    Plaza Wine & Craft Beer  60.169200  24.934983
# 5                     Kaisla  60.171878  24.947378
# 6                      Runar  60.166330  24.949431
# 7               Sori Taproom  60.171963  24.947435
# 8                        Bro  60.177036  24.951549
# 9                 Bar Llamas  60.163469  24.942379
# 10                Bar Favela  60.172056  24.920077
# 11           Pub Peräkammari  60.167797  24.937183
# 12          Punavuoren Ahven  60.161082  24.937536
# ...

# %%
db = client.ironhack
collection = db.nightclubs
collection.create_index ([("geometry", GEOSPHERE)])
# Out:
# 'geometry_2dsphere'

# %%
data = gdf3.to_dict(orient='records')
collection.insert_many(data)

# %%
data[:5]
# Out:
# [{'name': 'Liberty or Death',
#   'latitud': 60.16469982956184,
#   'longitud': 24.944248795509335,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.944248795509335, 60.16469982956184)},
#   '_id': ObjectId('602164b3bda0fd886bdf4fe5')},
#  {'name': 'KirjaClub',
#   'latitud': 60.176467430909206,
#   'longitud': 24.956222434547158,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.956222434547158, 60.176467430909206)},
#   '_id': ObjectId('602164b3bda0fd886bdf4fe6')},
#  {'name': 'Apéro',
#   'latitud': 60.16421142755892,
#   'longitud': 24.92948055267334,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.92948055267334, 60.16421142755892)},
#   '_id': ObjectId('602164b3bda0fd886bdf4fe7')},
#  {'name': 'Olutravintola Pikkulintu',
#   'latitud': 60.1658932577839,
#   'longitud': 24.93686519981724,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.93686519981724, 60.1658932577839)},
#   '_id': ObjectId('602164b3bda0fd886bdf4fe8')},
# ...

# %%
cercano3 = db.nightclubs.find({"geometry":{"$near":{"type":"Point", "coordinates":[60.171821,24.945167]}}})
list(cercano3)[:5]
# Out:
# [{'_id': ObjectId('60212f89235f9908d38c87e5'),
#   'name': 'Bar Haven',
#   'latitud': 60.16654471941996,
#   'longitud': 24.9513536704468,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.9513536704468, 60.16654471941996]}},
#  {'_id': ObjectId('60213075235f9908d38c87fe'),
#   'name': 'Bar Haven',
#   'latitud': 60.16654471941996,
#   'longitud': 24.9513536704468,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.9513536704468, 60.16654471941996]}},
#  {'_id': ObjectId('602164b3bda0fd886bdf4ff6'),
#   'name': 'Bar Haven',
#   'latitud': 60.16654471941996,
#   'longitud': 24.9513536704468,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.9513536704468, 60.16654471941996]}},
#  {'_id': ObjectId('60212f89235f9908d38c87da'),
#   'name': 'Runar',
#   'latitud': 60.16632954758476,
#   'longitud': 24.949430865771262,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.949430865771262, 60.16632954758476]}},
#  {'_id': ObjectId('60213075235f9908d38c87f3'),
# ...

# %% [markdown]
# ### El nightclub más cercano es :
#     Bar Haven
#     latitud': 60.16654471941996
#     longitud': 24.9513536704468

# %% [markdown]
# ## Cuarta llamada: Starbucks

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"{emp1.get('coordinates')[1]},{emp1.get('coordinates')[0]}",
              "query": "Starbucks",
              "limit": 10,
              "radius": 500
         }
resp = requests.get(url=url1, params=params)
strdata = json.loads(resp.text)

# %%
strdata.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = strdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
star = decoded.get("items")

# %%
mapastar_nombre = ["venue","name"]
mapastar_latitud = ["venue","location","lat"]
mapastar_longitud = ["venue","location","lng"]

# %%
print(getFromDict(star[0],mapastar_nombre))
print(getFromDict(star[0],mapastar_latitud))
print(getFromDict(star[0],mapastar_longitud))
# Out:
# Starbucks
# 60.167736932209785
# 24.94336882366579

# %%
starbucks = []
for dic in star:
    st = {}
    st["name"] = getFromDict(dic,mapa_nombre)
    st["latitud"] = getFromDict(dic,m_latitud)
    st["longitud"] = getFromDict(dic,m_longitud)
    starbucks.append(st)

# %%
starbucks[0]
# Out:
# {'name': 'Starbucks',
#  'latitud': 60.167736932209785,
#  'longitud': 24.94336882366579}

# %%
#Al comprobar los starbucks, me doy cuenta que existe sólo uno en Helsinki y me muestra otras categorías. 
df_st = pd.DataFrame(starbucks)
df_st.head()
# Out:
#                      name    latitud   longitud
# 0               Starbucks  60.167737  24.943369
# 1         Robert's Coffee  60.169206  24.941611
# 2              Café Aalto  60.167825  24.943540
# 3  Robert's Coffee Netcup  60.168703  24.940922
# 4         Robert's Coffee  60.171241  24.941166

# %%
gdf4 = gpd.GeoDataFrame(df_st, geometry = gpd.points_from_xy(df_st.longitud,df_st.latitud))
gdf4.head()
# Out:
#                      name    latitud   longitud                   geometry
# 0               Starbucks  60.167737  24.943369  POINT (24.94337 60.16774)
# 1         Robert's Coffee  60.169206  24.941611  POINT (24.94161 60.16921)
# 2              Café Aalto  60.167825  24.943540  POINT (24.94354 60.16783)
# 3  Robert's Coffee Netcup  60.168703  24.940922  POINT (24.94092 60.16870)
# 4         Robert's Coffee  60.171241  24.941166  POINT (24.94117 60.17124)

# %%
Map(Layer(gdf4, popup_hover = [popup_element("name","Starbucks")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### El Starbucks más cercano es :
#
#     Starbucks
#     latitud: 60.167737
#     longitud: 24.943369

# %% [markdown]
# ## Quinta llamada: Restaurante Vegano

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"{emp1.get('coordinates')[1]},{emp1.get('coordinates')[0]}",
              "query": "Vegan Restaurant",
              "limit": 20,
              "radius": 2000
         }
resp = requests.get(url=url1, params=params)
vegdata = json.loads(resp.text)

# %%
decoding_data = vegdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
vegg = decoded.get("items")

# %%
mapavegg_nombre = ["venue","name"]
mapavegg_latitud = ["venue","location","lat"]
mapavegg_longitud = ["venue","location","lng"]

# %%
print(getFromDict(vegg[0],mapavegg_nombre))
print(getFromDict(vegg[0],mapavegg_latitud))
print(getFromDict(vegg[0],mapavegg_longitud))
# Out:
# Zucchini
# 60.16616033742283
# 24.949550935785922

# %%
vegano = []
for dic in vegg:
    vg = {}
    vg["name"] = getFromDict(dic,mapavegg_nombre)
    vg["latitud"] = getFromDict(dic,mapavegg_latitud)
    vg["longitud"] = getFromDict(dic,mapavegg_longitud)
    vegano.append(vg)

# %%
vegano[0]
# Out:
# {'name': 'Zucchini',
#  'latitud': 60.16616033742283,
#  'longitud': 24.949550935785922}

# %%
df_vg = pd.DataFrame(vegano)
df_vg.head()
# Out:
#             name    latitud   longitud
# 0       Zucchini  60.166160  24.949551
# 1  Roots Kitchen  60.179254  24.951582
# 2          Qulma  60.171590  24.956639
# 3    Yes Yes Yes  60.164187  24.943998
# 4         Levant  60.164131  24.936531

# %%
gdf5 = gpd.GeoDataFrame(df_vg, geometry = gpd.points_from_xy(df_vg.longitud,df_vg.latitud))
gdf5.head()
# Out:
#             name    latitud   longitud                   geometry
# 0       Zucchini  60.166160  24.949551  POINT (24.94955 60.16616)
# 1  Roots Kitchen  60.179254  24.951582  POINT (24.95158 60.17925)
# 2          Qulma  60.171590  24.956639  POINT (24.95664 60.17159)
# 3    Yes Yes Yes  60.164187  24.943998  POINT (24.94400 60.16419)
# 4         Levant  60.164131  24.936531  POINT (24.93653 60.16413)

# %%
Map(Layer(gdf5, popup_hover = [popup_element("name","Venga Restaurant")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# ### ¿Cuál es el restaurante vegano más cercano a mi empresa?

# %%
gdf5['geometry']=gdf5['geometry'].apply(lambda x:shapely.geometry.mapping(x))
gdf5
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
#                     name    latitud   longitud  \
# 0               Zucchini  60.166160  24.949551
# 1          Roots Kitchen  60.179254  24.951582
# 2                  Qulma  60.171590  24.956639
# 3            Yes Yes Yes  60.164187  24.943998
# 4                 Levant  60.164131  24.936531
# 5                   Magu  60.163830  24.946299
# 6              Silvoplee  60.181398  24.949064
# 7               Sen Chay  60.177595  24.950797
# 8                 Fafa's  60.169105  24.933750
# 9                  OmNam  60.168093  24.935987
# 10       Classic & Vegan  60.179440  24.950385
# 11      Eat Your Greens!  60.169102  24.948195
# 12            Loving Hut  60.182881  24.948376
# 13                Levant  60.188394  24.954584
# ...

# %%
db = client.ironhack
collection = db.veganos
collection.create_index ([("geometry", GEOSPHERE)])
# Out:
# 'geometry_2dsphere'

# %%
data = gdf5.to_dict(orient='records')
collection.insert_many(data)

# %%
data[:5]
# Out:
# [{'name': 'Zucchini',
#   'latitud': 60.16616033742283,
#   'longitud': 24.949550935785922,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.949550935785922, 60.16616033742283)},
#   '_id': ObjectId('602164e5bda0fd886bdf4ffe')},
#  {'name': 'Roots Kitchen',
#   'latitud': 60.17925390601578,
#   'longitud': 24.951581663171815,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.951581663171815, 60.17925390601578)},
#   '_id': ObjectId('602164e5bda0fd886bdf4fff')},
#  {'name': 'Qulma',
#   'latitud': 60.17158999776495,
#   'longitud': 24.95663906516804,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.95663906516804, 60.17158999776495)},
#   '_id': ObjectId('602164e5bda0fd886bdf5000')},
#  {'name': 'Yes Yes Yes',
#   'latitud': 60.164187,
#   'longitud': 24.943998,
#   'geometry': {'type': 'Point', 'coordinates': (24.943998, 60.164187)},
#   '_id': ObjectId('602164e5bda0fd886bdf5001')},
#  {'name': 'Levant',
#   'latitud': 60.164130694350206,
# ...

# %%
cercano5 = db.veganos.find({"geometry":{"$near":{"type":"Point", "coordinates":[60.171821,24.945167]}}})
list(cercano5)[:5]
# Out:
# [{'_id': ObjectId('602137dc235f9908d38c8816'),
#   'name': 'Pontus',
#   'latitud': 60.1587920757416,
#   'longitud': 24.94628194859813,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.94628194859813, 60.1587920757416]}},
#  {'_id': ObjectId('602164e5bda0fd886bdf500e'),
#   'name': 'Pontus',
#   'latitud': 60.1587920757416,
#   'longitud': 24.94628194859813,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.94628194859813, 60.1587920757416]}},
#  {'_id': ObjectId('602137dc235f9908d38c880b'),
#   'name': 'Magu',
#   'latitud': 60.16383,
#   'longitud': 24.946299,
#   'geometry': {'type': 'Point', 'coordinates': [24.946299, 60.16383]}},
#  {'_id': ObjectId('602164e5bda0fd886bdf5003'),
#   'name': 'Magu',
#   'latitud': 60.16383,
#   'longitud': 24.946299,
#   'geometry': {'type': 'Point', 'coordinates': [24.946299, 60.16383]}},
#  {'_id': ObjectId('602137dc235f9908d38c8806'),
#   'name': 'Zucchini',
#   'latitud': 60.16616033742283,
# ...

# %% [markdown]
# ### El Restaurante vegano más cercano es :
#
#     Pontus
#     latitud: 60.1587920757416
#     longitud: 24.94628194859813
