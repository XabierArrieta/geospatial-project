# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Mi-empresa" data-toc-modified-id="Mi-empresa-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Mi empresa</a></span></li><li><span><a href="#API-Foursquare." data-toc-modified-id="API-Foursquare.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>API Foursquare.</a></span><ul class="toc-item"><li><span><a href="#Primera-llamada:-Aeropuerto" data-toc-modified-id="Primera-llamada:-Aeropuerto-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Primera llamada: Aeropuerto</a></span><ul class="toc-item"><li><span><a href="#El-aeropuerto-más-cercano-está-a-19,5km-:" data-toc-modified-id="El-aeropuerto-más-cercano-está-a-19,5km-:-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>El aeropuerto más cercano está a 19,5km :</a></span></li></ul></li><li><span><a href="#Segunda-llamada:-Nursery-School" data-toc-modified-id="Segunda-llamada:-Nursery-School-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Segunda llamada: Nursery School</a></span><ul class="toc-item"><li><span><a href="#¿Cuál-de-las-Nurseries-está-más-cerca-de-mi-empresa?" data-toc-modified-id="¿Cuál-de-las-Nurseries-está-más-cerca-de-mi-empresa?-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>¿Cuál de las Nurseries está más cerca de mi empresa?</a></span></li><li><span><a href="#La-Nursery-más-cercana-está-a--2,5km:" data-toc-modified-id="La-Nursery-más-cercana-está-a--2,5km:-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>La Nursery más cercana está a  2,5km:</a></span></li></ul></li><li><span><a href="#Tercera-llamada:-Nightclubs" data-toc-modified-id="Tercera-llamada:-Nightclubs-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Tercera llamada: Nightclubs</a></span><ul class="toc-item"><li><span><a href="#¿Dónde-está-el-Nightclub-más-cercano-a-mi-empresa?" data-toc-modified-id="¿Dónde-está-el-Nightclub-más-cercano-a-mi-empresa?-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>¿Dónde está el Nightclub más cercano a mi empresa?</a></span></li><li><span><a href="#El-nightclub-más-cercano-está-a-1,7km-:" data-toc-modified-id="El-nightclub-más-cercano-está-a-1,7km-:-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>El nightclub más cercano está a 1,7km :</a></span></li></ul></li><li><span><a href="#Cuarta-llamada:-Starbucks" data-toc-modified-id="Cuarta-llamada:-Starbucks-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Cuarta llamada: Starbucks</a></span><ul class="toc-item"><li><span><a href="#El-Starbucks-más-cercano-está-a-500m:" data-toc-modified-id="El-Starbucks-más-cercano-está-a-500m:-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>El Starbucks más cercano está a 500m:</a></span></li></ul></li><li><span><a href="#Quinta-llamada:-Restaurante-Vegano" data-toc-modified-id="Quinta-llamada:-Restaurante-Vegano-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Quinta llamada: Restaurante Vegano</a></span><ul class="toc-item"><li><span><a href="#¿Cuál-es-el-restaurante-vegano-más-cercano-a-mi-empresa?" data-toc-modified-id="¿Cuál-es-el-restaurante-vegano-más-cercano-a-mi-empresa?-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>¿Cuál es el restaurante vegano más cercano a mi empresa?</a></span></li><li><span><a href="#El-Restaurante-vegano-más-cercano-está-a-1.5km:" data-toc-modified-id="El-Restaurante-vegano-más-cercano-está-a-1.5km:-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>El Restaurante vegano más cercano está a 1.5km:</a></span></li></ul></li></ul></li></ul></div>

# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
from functools import reduce
import operator
import geopandas as gpd
from pymongo import MongoClient,GEOSPHERE
import shapely.geometry
import geopandas as gpd
from cartoframes.viz import Map, Layer, popup_element
import sys
sys.path.append("../")
import src.funcionesok as fun

# %% [markdown]
# #  Mi empresa
# Teniendo en cuenta mi empresa hago llamadas a la API.

# %%
company = "21 Mikonkatu, Helsinki FI 00100"

# %%
suomi = pd.read_csv('../data/dataOK.csv', encoding = 'ISO - 8859-1')
suomi
# Out:
#        city country_code   latitude  longitude   name category_code  \
# 0  Helsinki          FIN  60.171821  24.945167  Apaja   games_video
#
#    number_of_employees  founded_year
# 0                   44          2001

# %%
fun.geocode(company)
# Out:
# {'type': 'Point', 'coordinates': [60.17212, 24.94519]}

# %%
load_dotenv()
# Out:
# True

# %%
tok1 = os.getenv("tok1")
tok2 = os.getenv("tok2")

# %% [markdown]
# # API Foursquare.
#
# Una vez seleccionada la oficina perfecta que cumple nuestras necesidades vamos a comprobar mediante la API de Foursquare los siguientes puntos;
# - Los Account managers viajan mucho. Voy a busar un aeropuerto en un radio de 20kms.
# - El 30% de los empleados de la compañía tiene al menos un niño. Voy a buscar guarderías en un radio de 5km.
# - La edad de los trabajadores oscila entre 25 y 40 años. Voy a buscar discotecas en un radio de 10km.
# - A los ejecutivos les gusta mucho la cadena de cafés "Starbucks". Voy a buscar Starbucks en un radio de 500m.
# - La CEO de la compañía es vegana. Voy a buscar restaurantes veganos en un radio de 2km.

# %% [markdown]
# ## Primera llamada: Aeropuerto

# %%
fun.geo_api()
# Out:
# ¿Qué quieres buscar en Foursquare?
# Airport
# ¿Cuántas búsquedas quieres que muestre?
# 1
# ¿En qué radio?(medida = metros)
# 20000
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %%
emp1:

# %%
url1= 'https://api.foursquare.com/v2/venues/explore'

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"60.17212, 24.94519",
              "query": "Airport",
              "limit": 1,
              "radius": 20000,
             }

# %%
resp = requests.get(url=url1, params=params)
airdata = json.loads(resp.text)

# %%
airdata.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = airdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
airp = decoded.get("items")

# %%
mapa_nombre = ["venue","name"]
m_latitud = ["venue","location","lat"]
m_longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce (operator.getitem,mapa,diccionario)

# %%
print(getFromDict(airp[0],mapa_nombre))
# Out:
# Helsinki Airport (HEL) (Helsinki-Vantaan lentoasema)

# %%
print(getFromDict(airp[0],m_latitud))
# Out:
# 60.31912855684579

# %%
print(getFromDict(airp[0],m_longitud))
# Out:
# 24.968297481536865

# %%
aeropuerto = []
for dic in airp:
    ai = {}
    ai["name"] = getFromDict(dic,mapa_nombre)
    ai["latitud"] = getFromDict(dic,m_latitud)
    ai["longitud"] = getFromDict(dic,m_longitud)
    aeropuerto.append(ai)

# %%
aeropuerto[0]
# Out:
# {'name': 'Helsinki Airport (HEL) (Helsinki-Vantaan lentoasema)',
#  'latitud': 60.31912855684579,
#  'longitud': 24.968297481536865}

# %%
dataframefinal = pd.DataFrame(aeropuerto)
dataframefinal.head()
# Out:
#                                                 name    latitud   longitud
# 0  Helsinki Airport (HEL) (Helsinki-Vantaan lento...  60.319129  24.968297

# %%
gdf = gpd.GeoDataFrame(dataframefinal, geometry = gpd.points_from_xy(dataframefinal.longitud,dataframefinal.latitud))
gdf.head()
# Out:
#                                                 name    latitud   longitud  \
# 0  Helsinki Airport (HEL) (Helsinki-Vantaan lento...  60.319129  24.968297
#
#                     geometry
# 0  POINT (24.96830 60.31913)

# %%
#Creo un mapa con el punto selecccionado

# %%
Map(Layer(gdf, popup_hover = [popup_element("name","Airport")]))

# %% [markdown]
# ### El aeropuerto más cercano está a 19,5km :
#     Helsinki Airport (HEL) (Helsinki-Vantaan lentoasema)
#     latitud: 60.319129
#     longitud: 24.968297

# %%
fun.geo_api()
# Out:
# ¿Qué quieres buscar en Foursquare?
# Nursery School
# ¿Cuántas búsquedas quieres que muestre?
# 10
# ¿En qué radio?(medida = metros)
# 5000
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %% [markdown]
# ## Segunda llamada: Nursery School

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"60.17212, 24.94519",
              "query": "Nursery School",
              "limit": 10,
              "radius": 5000
             }

# %%
resp = requests.get(url=url1, params=params)
nurdata = json.loads(resp.text)

# %%
nurdata.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = nurdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
nur = decoded.get("items")

# %%
mapan_nombre = ["venue","name"]
mn_latitud = ["venue","location","lat"]
mn_longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce (operator.getitem,mapa,diccionario)

# %%
print(getFromDict(nur[0],mapan_nombre))
print(getFromDict(nur[0],mn_latitud))
print(getFromDict(nur[0],mn_longitud))
# Out:
# Daghemmet B. E. Von Schantz
# 60.158121
# 24.936681

# %%
nurseries = []
for dic in nur:
    nr = {}
    nr["name"] = getFromDict(dic,mapa_nombre)
    nr["latitud"] = getFromDict(dic,m_latitud)
    nr["longitud"] = getFromDict(dic,m_longitud)
    nurseries.append(nr)

# %%
nurseries[0]
# Out:
# {'name': 'Daghemmet B. E. Von Schantz',
#  'latitud': 60.158121,
#  'longitud': 24.936681}

# %%
df_nur = pd.DataFrame(nurseries)
df_nur.head()
# Out:
#                              name    latitud   longitud
# 0     Daghemmet B. E. Von Schantz  60.158121  24.936681
# 1  lauttasaari english playschool  60.158857  24.877429
# 2             Päiväkoti Kesäheinä  60.202455  24.951274
# 3               Päiväkoti Marjala  60.209475  24.964812

# %%
gdf2 = gpd.GeoDataFrame(df_nur, geometry = gpd.points_from_xy(df_nur.longitud,df_nur.latitud))
gdf2.head()
# Out:
#                              name    latitud   longitud  \
# 0     Daghemmet B. E. Von Schantz  60.158121  24.936681
# 1  lauttasaari english playschool  60.158857  24.877429
# 2             Päiväkoti Kesäheinä  60.202455  24.951274
# 3               Päiväkoti Marjala  60.209475  24.964812
#
#                     geometry
# 0  POINT (24.93668 60.15812)
# 1  POINT (24.87743 60.15886)
# 2  POINT (24.95127 60.20246)
# 3  POINT (24.96481 60.20948)

# %%
Map(Layer(gdf2, popup_hover = [popup_element("name","Nursery School")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %% [markdown]
# ### ¿Cuál de las Nurseries está más cerca de mi empresa?

# %%
gdf2['geometry']=gdf2['geometry'].apply(lambda x:shapely.geometry.mapping(x))
gdf2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-db73d93c656a> in <module>
# ----> 1 gdf2['geometry']=gdf2['geometry'].apply(lambda x:shapely.geometry.mapping(x))
#       2 gdf2
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-48-db73d93c656a> in <lambda>(x)
# ----> 1 gdf2['geometry']=gdf2['geometry'].apply(lambda x:shapely.geometry.mapping(x))
#       2 gdf2
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/shapely/geometry/geo.py in mapping(ob)
#     203     {'type': 'Point', 'coordinates': (0.0, 0.0)}
#     204     """
# --> 205     return ob.__geo_interface__
#
# AttributeError: 'dict' object has no attribute '__geo_interface__'

# %%
client = MongoClient()
db = client.ironhack
collection = db.nurseries
collection.create_index ([("geometry", GEOSPHERE)])
# Out:
# 'geometry_2dsphere'

# %%
data = gdf2.to_dict(orient='records')
collection.insert_many(data)

# %%
data
# Out:
# [{'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': (24.936681, 60.158121)},
#   '_id': ObjectId('6021b00806255645aa2c526f')},
#  {'name': 'lauttasaari english playschool',
#   'latitud': 60.158857316461074,
#   'longitud': 24.877429136253458,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.877429136253458, 60.158857316461074)},
#   '_id': ObjectId('6021b00806255645aa2c5270')},
#  {'name': 'Päiväkoti Kesäheinä',
#   'latitud': 60.20245514603548,
#   'longitud': 24.95127417000266,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.95127417000266, 60.20245514603548)},
#   '_id': ObjectId('6021b00806255645aa2c5271')},
#  {'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': (24.964811971036774, 60.20947535503745)},
#   '_id': ObjectId('6021b00806255645aa2c5272')}]

# %%
cercano2 = db.nurseries.find({"geometry":{"$near":{"type":"Point", "coordinates":[60.171821,24.945167]}}})
list(cercano2)
# Out:
# [{'_id': ObjectId('60212ef3235f9908d38c87d0'),
#   'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': [24.936681, 60.158121]}},
#  {'_id': ObjectId('6021b00806255645aa2c526f'),
#   'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': [24.936681, 60.158121]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe1'),
#   'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': [24.936681, 60.158121]}},
#  {'_id': ObjectId('6021a68b0a89d8e223fafa20'),
#   'name': 'Daghemmet B. E. Von Schantz',
#   'latitud': 60.158121,
#   'longitud': 24.936681,
#   'geometry': {'type': 'Point', 'coordinates': [24.936681, 60.158121]}},
#  {'_id': ObjectId('6021b00806255645aa2c5272'),
#   'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.964811971036774, 60.20947535503745]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe4'),
#   'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.964811971036774, 60.20947535503745]}},
#  {'_id': ObjectId('60212ef3235f9908d38c87d3'),
#   'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.964811971036774, 60.20947535503745]}},
#  {'_id': ObjectId('6021a68b0a89d8e223fafa23'),
#   'name': 'Päiväkoti Marjala',
#   'latitud': 60.20947535503745,
#   'longitud': 24.964811971036774,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.964811971036774, 60.20947535503745]}},
#  {'_id': ObjectId('60212ef3235f9908d38c87d2'),
#   'name': 'Päiväkoti Kesäheinä',
#   'latitud': 60.20245514603548,
#   'longitud': 24.95127417000266,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.95127417000266, 60.20245514603548]}},
#  {'_id': ObjectId('6021b00806255645aa2c5271'),
#   'name': 'Päiväkoti Kesäheinä',
#   'latitud': 60.20245514603548,
#   'longitud': 24.95127417000266,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.95127417000266, 60.20245514603548]}},
#  {'_id': ObjectId('6021a68b0a89d8e223fafa22'),
#   'name': 'Päiväkoti Kesäheinä',
#   'latitud': 60.20245514603548,
#   'longitud': 24.95127417000266,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.95127417000266, 60.20245514603548]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe3'),
#   'name': 'Päiväkoti Kesäheinä',
#   'latitud': 60.20245514603548,
#   'longitud': 24.95127417000266,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.95127417000266, 60.20245514603548]}},
#  {'_id': ObjectId('60212ef3235f9908d38c87d1'),
#   'name': 'lauttasaari english playschool',
#   'latitud': 60.158857316461074,
#   'longitud': 24.877429136253458,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.877429136253458, 60.158857316461074]}},
#  {'_id': ObjectId('602164a3bda0fd886bdf4fe2'),
#   'name': 'lauttasaari english playschool',
#   'latitud': 60.158857316461074,
#   'longitud': 24.877429136253458,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.877429136253458, 60.158857316461074]}},
#  {'_id': ObjectId('6021a68b0a89d8e223fafa21'),
#   'name': 'lauttasaari english playschool',
#   'latitud': 60.158857316461074,
#   'longitud': 24.877429136253458,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.877429136253458, 60.158857316461074]}},
#  {'_id': ObjectId('6021b00806255645aa2c5270'),
#   'name': 'lauttasaari english playschool',
#   'latitud': 60.158857316461074,
#   'longitud': 24.877429136253458,
#   'geometry': {'type': 'Point',
#    'coordinates': [24.877429136253458, 60.158857316461074]}}]

# %% [markdown]
# ### La Nursery más cercana está a  2,5km:
#     Daghemmet B. E. Von Schantz
#     latitud': 60.158121
#     longitud': 24.936681

# %% [markdown]
# ## Tercera llamada: Nightclubs

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"60.17212, 24.94519",
              "query": "Nightlife Spot",
              "limit": 25,
              "radius": 7500 
         }
resp = requests.get(url=url1, params=params)
nidata = json.loads(resp.text)

# %%
nidata.keys()

# %%
decoding_data = nidata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
nic = decoded.get("items")

# %%
mapani_nombre = ["venue","name"]
mapani_latitud = ["venue","location","lat"]
mapani_longitud = ["venue","location","lng"]

# %%
print(getFromDict(nic[0],mapa_nombre))
print(getFromDict(nic[0],m_latitud))
print(getFromDict(nic[0],m_longitud))

# %%
nightclubs = []
for dic in nic:
    nc = {}
    nc["name"] = getFromDict(dic,mapa_nombre)
    nc["latitud"] = getFromDict(dic,m_latitud)
    nc["longitud"] = getFromDict(dic,m_longitud)
    nightclubs.append(nc)

# %%
nightclubs[0]

# %%
df_nc = pd.DataFrame(nightclubs)
df_nc.head()

# %%
gdf3 = gpd.GeoDataFrame(df_nc, geometry = gpd.points_from_xy(df_nc.longitud,df_nc.latitud))
gdf3.head()

# %%
Map(Layer(gdf3, popup_hover = [popup_element("name","Night Club")]))

# %% [markdown]
# ### ¿Dónde está el Nightclub más cercano a mi empresa?

# %%
gdf3['geometry']=gdf3['geometry'].apply(lambda x:shapely.geometry.mapping(x))
gdf3

# %%
db = client.ironhack
collection = db.nightclubs
collection.create_index ([("geometry", GEOSPHERE)])

# %%
data = gdf3.to_dict(orient='records')
collection.insert_many(data)

# %%
data[:5]

# %%
cercano3 = db.nightclubs.find({"geometry":{"$near":{"type":"Point", "coordinates":[60.171821,24.945167]}}})
list(cercano3)[:5]

# %% [markdown]
# ### El nightclub más cercano está a 1,7km :
#     Bar Haven
#     latitud': 60.16654471941996
#     longitud': 24.9513536704468

# %% [markdown]
# ## Cuarta llamada: Starbucks

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"60.17212, 24.94519",
              "query": "Starbucks",
              "limit": 10,
              "radius": 500
         }
resp = requests.get(url=url1, params=params)
strdata = json.loads(resp.text)

# %%
strdata.keys()

# %%
decoding_data = strdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
star = decoded.get("items")

# %%
mapastar_nombre = ["venue","name"]
mapastar_latitud = ["venue","location","lat"]
mapastar_longitud = ["venue","location","lng"]

# %%
print(getFromDict(star[0],mapastar_nombre))
print(getFromDict(star[0],mapastar_latitud))
print(getFromDict(star[0],mapastar_longitud))

# %%
starbucks = []
for dic in star:
    st = {}
    st["name"] = getFromDict(dic,mapa_nombre)
    st["latitud"] = getFromDict(dic,m_latitud)
    st["longitud"] = getFromDict(dic,m_longitud)
    starbucks.append(st)

# %%
starbucks[0]

# %%
#Al comprobar los starbucks, me doy cuenta que existe sólo uno en Helsinki y me muestra otras categorías. 
df_st = pd.DataFrame(starbucks)
df_st.head()

# %%
gdf4 = gpd.GeoDataFrame(df_st, geometry = gpd.points_from_xy(df_st.longitud,df_st.latitud))
gdf4.head()

# %%
Map(Layer(gdf4, popup_hover = [popup_element("name","Starbucks")]))

# %% [markdown]
# ### El Starbucks más cercano está a 500m:
#
#     Starbucks
#     latitud: 60.167737
#     longitud: 24.943369

# %% [markdown]
# ## Quinta llamada: Restaurante Vegano

# %%
params = {"client_id" : tok1,
              "client_secret" : tok2,
              "v": "20180323",
              "ll": f"60.17212, 24.94519",
              "query": "Vegan Restaurant",
              "limit": 20,
              "radius": 2000
         }
resp = requests.get(url=url1, params=params)
vegdata = json.loads(resp.text)

# %%
decoding_data = vegdata.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
vegg = decoded.get("items")

# %%
mapavegg_nombre = ["venue","name"]
mapavegg_latitud = ["venue","location","lat"]
mapavegg_longitud = ["venue","location","lng"]

# %%
print(getFromDict(vegg[0],mapavegg_nombre))
print(getFromDict(vegg[0],mapavegg_latitud))
print(getFromDict(vegg[0],mapavegg_longitud))

# %%
vegano = []
for dic in vegg:
    vg = {}
    vg["name"] = getFromDict(dic,mapavegg_nombre)
    vg["latitud"] = getFromDict(dic,mapavegg_latitud)
    vg["longitud"] = getFromDict(dic,mapavegg_longitud)
    vegano.append(vg)

# %%
vegano[0]

# %%
df_vg = pd.DataFrame(vegano)
df_vg.head()

# %%
gdf5 = gpd.GeoDataFrame(df_vg, geometry = gpd.points_from_xy(df_vg.longitud,df_vg.latitud))
gdf5.head()

# %%
Map(Layer(gdf5, popup_hover = [popup_element("name","Venga Restaurant")]))

# %% [markdown]
# ### ¿Cuál es el restaurante vegano más cercano a mi empresa?

# %%
gdf5['geometry']=gdf5['geometry'].apply(lambda x:shapely.geometry.mapping(x))
gdf5

# %%
db = client.ironhack
collection = db.veganos
collection.create_index ([("geometry", GEOSPHERE)])

# %%
data = gdf5.to_dict(orient='records')
collection.insert_many(data)

# %%
data[:5]

# %%
cercano5 = db.veganos.find({"geometry":{"$near":{"type":"Point", "coordinates":[60.171821,24.945167]}}})
list(cercano5)[:5]

# %% [markdown]
# ### El Restaurante vegano más cercano está a 1.5km:
#
#     Pontus
#     latitud: 60.1587920757416
#     longitud: 24.94628194859813
